# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import json 
import numpy as np 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-e41f9f93-b402-46a3-ba19-89026199532b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e41f9f93-b402-46a3-ba19-89026199532b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving intents.json to intents.json

# %%
with open('intents.json') as file:
    data = json.load(file)
    
data
# Out:
# {'intents': [{'context_set': '',
#    'patterns': ['Hi',
#     'How are you',
#     'Is anyone there?',
#     'Hello',
#     'Good day',
#     'Hey'],
#    'responses': ['Hello, thanks for visiting',
#     'Good to see you again',
#     'Hi there, how can I help?'],
#    'tag': 'greeting'},
#   {'patterns': ['Bye', 'See you later', 'Goodbye', 'okay bye', 'exit'],
#    'responses': ['See you later, thanks for visiting',
#     'Have a nice day',
#     'Bye! Come back again soon.'],
#    'tag': 'goodbye'},
#   {'patterns': ['Who are you',
#     'What are you',
#     'What is your name ',
#     'what should I call you',
#     'whats your name?'],
#    'responses': ['I am JARVIS',
#     'My name is JARVIS and I am your virtual assistant'],
#    'tag': 'about'},
#   {'patterns': [],
#    'responses': ["Sorry, can't understand you",
#     'Please give me more info',
#     'Not sure I understand'],
#    'tag': 'noanswer'},
#   {'patterns': ['Thanks', 'Thank you', "That's helpful", 'okay'],
#    'responses': ['Happy to help!', 'Any time!', 'My pleasure'],
#    'tag': 'thanks'},
#   {'patterns': ['Could you help me?',
#     'give me a hand please',
#     'Can you help?',
#     'What can you do for me?',
#     'I need a support',
#     'I need a help',
#     'support me please',
#     'help'],
#    'responses': ['Tell me how can assist you',
#     'Tell me your problem to assist you',
#     'Yes Sure, How can I support you'],
#    'tag': 'help'},
#   {'patterns': ['What hours are you open?',
#     'What are your hours?',
#     'When are you open?',
#     'what are your timings'],
#    'responses': ["We're open every day 9am-9pm",
#     'Our hours are 9am-9pm every day'],
#    'tag': 'hours'},
#   {'patterns': ['What is your location?',
#     'Where are you located?',
#     'What is your address?',
#     'Where is your restaurant situated?',
#     'location',
#     'address',
#     'give me your address',
#     'tell your address'],
#    'responses': ['Stark Restaurant Saket near max Hospital',
#     'Our Address is: Stark Restaurant Saket, New Delhi - 110017, India'],
#    'tag': 'location'},
#   {'patterns': ['Do you take credit cards?',
#     'Do you accept Cash?',
#     'what payment method are available',
#     'modes of payment'],
#    'responses': ['We accept credit cards, cash, and paytm and phonepay',
#     'Online payment is available and cash and credit card payment method also available'],
#    'tag': 'payments'},
#   {'patterns': ['What is your menu for today?',
#     'What are you serving today?',
#     "What is today's special?",
#     "today's special"],
#    'responses': ["Today's special is Chicken Tikka",
#     'Our speciality for today is Chicken Tikka'],
#    'tag': 'todaysmenu'},
#   {'context_set': 'food',
#    'patterns': ['Do you provide home delivery?',
#     'Do you deliver the food?',
#     'What are the home delivery options?'],
#    'responses': ['Yes, we provide home delivery through UBER Eats and Zomato?',
#     'We have home delivery options through UBER Eats and Zomato'],
#    'tag': 'deliveryoption'},
#   {'context_filter': 'food',
#    'patterns': ['What is your Menu?',
#     'What are the main course options?',
#     'Can you tell me the most delicious dish from the menu?',
#     'What is the menu',
#     'menu'],
#    'responses': ['We have South Indian food, North Indian food, Chinese Food and Italian food',
#     'You can check out the food menu at www.mymenu.com',
#     'You can check various delicacies given in the food menu at www.mymenu.com'],
#    'tag': 'menu'},
#   {'patterns': ['South Indian',
#     'South Indian food',
#     'What are the South Indian options?'],
#    'responses': ['Masala Dosa, Sambar, Upma, Dosa, Idli Sambar, Vada Sambar, Onion Rava Dosa, Uttapam'],
#    'tag': 'Southindian'},
#   {'patterns': ['North Indian',
#     'North Indian food',
#     'What are the North Indian options?'],
#    'responses': ['Butter Chicken, Palak Paneer, Rajma Rice, Chicken Briyani, Mutton Biryani, Makhni Dal, Jalebi, Gulab Jamun, Curd, Butter Naan, Chapatti, Chole Bhature, Dum Aloo, Chicken Tikka, Aloo paratha, Rabri, Lassi, Faluda'],
#    'tag': 'Northindian'},
#   {'patterns': ['Veg', 'Vegetarian food', 'What are the Veg options?'],
#    'responses': ['Palak Paneer, Rajma Rice, Makhni Dal, Curd, Butter Naan, Chapatti, Chole Bhature, Dum Aloo, Aloo paratha, Rabri'],
#    'tag': 'Veg'},
#   {'patterns': ['Non veg', 'Non Veg food', 'What are the Non veg options?'],
#    'responses': ['Butter Chicken, Chicken Briyani, Mutton Biryani, Butter Naan, Chapatti, Chicken Tikka'],
#    'tag': 'Nonveg'},
#   {'patterns': ['Desert', 'Refreshments', 'What are the Desert options?'],
#    'responses': ['Jalebi, Gulab Jamun, Curd, Rabri, Lassi, Faluda'],
#    'tag': 'Desert'},
#   {'patterns': ['Chinese', 'What are the Chinese options?'],
#    'responses': ['Momos, Chowmein, Chilli Chicken, Spring Rolls, Chilli Potato, Fried Rice'],
#    'tag': 'Chinese'},
#   {'patterns': ['Italian', 'What are the Italian options?'],
#    'responses': ['Pizza, Lasagna, Ravioli, Spaghetti, Fried Eggplant, Red Wine'],
#    'tag': 'Italian'},
#   {'patterns': ['have a complaint',
#     'I want to raise a complaint',
#     'there is a complaint about a service'],
#    'responses': ['Please provide us your complaint in order to assist you',
#     'Please mention your complaint, we will reach you and sorry for any inconvenience caused'],
#    'tag': 'complaint'}]}

# %%
training_sentences = []
training_labels = []
labels = []
responses = []


for intent in data['intents']:
    for pattern in intent['patterns']:
        training_sentences.append(pattern)
        training_labels.append(intent['tag'])
    responses.append(intent['responses'])
    
    if intent['tag'] not in labels:
        labels.append(intent['tag'])
        
num_classes = len(labels)

# %%
lbl_encoder = LabelEncoder()
lbl_encoder.fit(training_labels)
training_labels = lbl_encoder.transform(training_labels)

# %%
vocab_size = 1000
embedding_dim = 20
max_len = 20
oov_token = "<OOV>"

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_token)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded_sequences = pad_sequences(sequences, truncating='post', maxlen=max_len)

# %%
model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length=max_len))
model.add(GlobalAveragePooling1D())
model.add(Dense(20, activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', 
              optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 20, 20)            20000
# _________________________________________________________________
# global_average_pooling1d_3 ( (None, 20)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_10 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_11 (Dense)             (None, 20)                420
# =================================================================
# Total params: 21,260
# Trainable params: 21,260
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(padded_sequences, np.array(training_labels), epochs=1000, batch_size=128)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 410ms/step - loss: 2.9961 - accuracy: 0.0513
# Epoch 2/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.9950 - accuracy: 0.0256
# Epoch 3/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9942 - accuracy: 0.0769
# Epoch 4/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.9934 - accuracy: 0.0769
# Epoch 5/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.9926 - accuracy: 0.0769
# Epoch 6/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.9918 - accuracy: 0.0769
# Epoch 7/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.9911 - accuracy: 0.0769
# Epoch 8/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.9903 - accuracy: 0.0769
# Epoch 9/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.9895 - accuracy: 0.0769
# Epoch 10/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.9886 - accuracy: 0.0769
# Epoch 11/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.9877 - accuracy: 0.0769
# Epoch 12/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.9867 - accuracy: 0.0769
# Epoch 13/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.9857 - accuracy: 0.0769
# Epoch 14/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9847 - accuracy: 0.0769
# Epoch 15/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9837 - accuracy: 0.0769
# Epoch 16/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.9827 - accuracy: 0.0769
# Epoch 17/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9817 - accuracy: 0.0769
# Epoch 18/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.9806 - accuracy: 0.0769
# Epoch 19/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9796 - accuracy: 0.0769
# Epoch 20/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.9785 - accuracy: 0.0769
# Epoch 21/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9774 - accuracy: 0.0769
# Epoch 22/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.9763 - accuracy: 0.0769
# Epoch 23/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.9752 - accuracy: 0.0769
# Epoch 24/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.9740 - accuracy: 0.0769
# Epoch 25/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.9728 - accuracy: 0.0769
# Epoch 26/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9716 - accuracy: 0.0769
# Epoch 27/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.9704 - accuracy: 0.0769
# Epoch 28/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.9691 - accuracy: 0.0769
# Epoch 29/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.9678 - accuracy: 0.0769
# Epoch 30/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.9665 - accuracy: 0.0769
# Epoch 31/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.9651 - accuracy: 0.0769
# Epoch 32/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9638 - accuracy: 0.0769
# Epoch 33/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.9624 - accuracy: 0.0769
# Epoch 34/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.9610 - accuracy: 0.0769
# Epoch 35/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.9596 - accuracy: 0.0769
# Epoch 36/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.9581 - accuracy: 0.0769
# Epoch 37/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.9566 - accuracy: 0.0769
# Epoch 38/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.9551 - accuracy: 0.0769
# Epoch 39/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.9536 - accuracy: 0.0769
# Epoch 40/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.9521 - accuracy: 0.0769
# Epoch 41/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.9505 - accuracy: 0.0769
# Epoch 42/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.9489 - accuracy: 0.0769
# Epoch 43/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9473 - accuracy: 0.0769
# Epoch 44/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9456 - accuracy: 0.0769
# Epoch 45/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.9439 - accuracy: 0.0769
# Epoch 46/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9422 - accuracy: 0.0769
# Epoch 47/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.9405 - accuracy: 0.0769
# Epoch 48/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.9388 - accuracy: 0.0769
# Epoch 49/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9370 - accuracy: 0.0769
# Epoch 50/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.9352 - accuracy: 0.0769
# Epoch 51/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.9334 - accuracy: 0.0769
# Epoch 52/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.9316 - accuracy: 0.0769
# Epoch 53/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.9298 - accuracy: 0.0769
# Epoch 54/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9279 - accuracy: 0.0769
# Epoch 55/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9260 - accuracy: 0.0769
# Epoch 56/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9242 - accuracy: 0.0769
# Epoch 57/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9222 - accuracy: 0.0769
# Epoch 58/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9203 - accuracy: 0.0769
# Epoch 59/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.9184 - accuracy: 0.0769
# Epoch 60/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.9164 - accuracy: 0.0769
# Epoch 61/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 2.9145 - accuracy: 0.0769
# Epoch 62/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9125 - accuracy: 0.0769
# Epoch 63/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9106 - accuracy: 0.0769
# Epoch 64/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.9086 - accuracy: 0.0769
# Epoch 65/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.9066 - accuracy: 0.0769
# Epoch 66/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9046 - accuracy: 0.0769
# Epoch 67/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.9026 - accuracy: 0.0769
# Epoch 68/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 2.9006 - accuracy: 0.0769
# Epoch 69/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.8985 - accuracy: 0.0769
# Epoch 70/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.8965 - accuracy: 0.0769
# Epoch 71/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8945 - accuracy: 0.0769
# Epoch 72/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.8924 - accuracy: 0.0769
# Epoch 73/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 2.8904 - accuracy: 0.0769
# Epoch 74/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.8883 - accuracy: 0.0769
# Epoch 75/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8863 - accuracy: 0.0769
# Epoch 76/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.8842 - accuracy: 0.0769
# Epoch 77/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.8821 - accuracy: 0.0769
# Epoch 78/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.8801 - accuracy: 0.0769
# Epoch 79/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 2.8780 - accuracy: 0.0769
# Epoch 80/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 2.8759 - accuracy: 0.0769
# Epoch 81/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.8738 - accuracy: 0.0769
# Epoch 82/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.8717 - accuracy: 0.0769
# Epoch 83/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 2.8695 - accuracy: 0.0769
# Epoch 84/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8674 - accuracy: 0.0769
# Epoch 85/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8653 - accuracy: 0.0769
# Epoch 86/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.8631 - accuracy: 0.0769
# Epoch 87/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8609 - accuracy: 0.0769
# Epoch 88/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8587 - accuracy: 0.0897
# Epoch 89/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.8565 - accuracy: 0.0897
# Epoch 90/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.8542 - accuracy: 0.1026
# Epoch 91/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.8520 - accuracy: 0.1410
# Epoch 92/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 2.8497 - accuracy: 0.1282
# Epoch 93/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.8474 - accuracy: 0.1154
# Epoch 94/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 2.8451 - accuracy: 0.1026
# Epoch 95/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 2.8427 - accuracy: 0.1026
# Epoch 96/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8403 - accuracy: 0.1026
# Epoch 97/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.8379 - accuracy: 0.1026
# Epoch 98/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.8355 - accuracy: 0.1026
# Epoch 99/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 2.8330 - accuracy: 0.1026
# Epoch 100/1000
# 1/1 [==============================] - 0s 16ms/step - loss: 2.8304 - accuracy: 0.1026
# Epoch 101/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.8279 - accuracy: 0.1026
# Epoch 102/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.8253 - accuracy: 0.1026
# Epoch 103/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.8226 - accuracy: 0.1026
# Epoch 104/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8199 - accuracy: 0.1026
# Epoch 105/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.8172 - accuracy: 0.1026
# Epoch 106/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8144 - accuracy: 0.1026
# Epoch 107/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.8116 - accuracy: 0.1026
# Epoch 108/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8087 - accuracy: 0.1026
# Epoch 109/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.8057 - accuracy: 0.1026
# Epoch 110/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8027 - accuracy: 0.1026
# Epoch 111/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.7997 - accuracy: 0.1026
# Epoch 112/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 2.7966 - accuracy: 0.1026
# Epoch 113/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.7934 - accuracy: 0.1026
# Epoch 114/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.7902 - accuracy: 0.1026
# Epoch 115/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.7869 - accuracy: 0.1026
# Epoch 116/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.7835 - accuracy: 0.1026
# Epoch 117/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.7801 - accuracy: 0.1026
# Epoch 118/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.7765 - accuracy: 0.1026
# Epoch 119/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.7729 - accuracy: 0.1026
# Epoch 120/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.7692 - accuracy: 0.1026
# Epoch 121/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.7655 - accuracy: 0.1026
# Epoch 122/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.7617 - accuracy: 0.1026
# Epoch 123/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 2.7578 - accuracy: 0.1026
# Epoch 124/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.7538 - accuracy: 0.1026
# Epoch 125/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.7497 - accuracy: 0.1026
# Epoch 126/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.7456 - accuracy: 0.1026
# Epoch 127/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.7413 - accuracy: 0.1026
# Epoch 128/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.7370 - accuracy: 0.1026
# Epoch 129/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.7326 - accuracy: 0.1026
# Epoch 130/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.7281 - accuracy: 0.1026
# Epoch 131/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.7235 - accuracy: 0.1026
# Epoch 132/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.7187 - accuracy: 0.1026
# Epoch 133/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 2.7136 - accuracy: 0.1026
# Epoch 134/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.7085 - accuracy: 0.1410
# Epoch 135/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 2.7033 - accuracy: 0.1410
# Epoch 136/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.6980 - accuracy: 0.1410
# Epoch 137/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 2.6928 - accuracy: 0.1410
# Epoch 138/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.6875 - accuracy: 0.1538
# Epoch 139/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.6821 - accuracy: 0.1667
# Epoch 140/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.6767 - accuracy: 0.1667
# Epoch 141/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.6711 - accuracy: 0.1795
# Epoch 142/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.6656 - accuracy: 0.1795
# Epoch 143/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.6599 - accuracy: 0.1795
# Epoch 144/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 2.6541 - accuracy: 0.1795
# Epoch 145/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 2.6483 - accuracy: 0.1795
# Epoch 146/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.6425 - accuracy: 0.1795
# Epoch 147/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.6365 - accuracy: 0.1923
# Epoch 148/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.6306 - accuracy: 0.1923
# Epoch 149/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.6245 - accuracy: 0.1923
# Epoch 150/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 2.6183 - accuracy: 0.1923
# Epoch 151/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.6121 - accuracy: 0.1923
# Epoch 152/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.6058 - accuracy: 0.1923
# Epoch 153/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.5994 - accuracy: 0.1923
# Epoch 154/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.5930 - accuracy: 0.1923
# Epoch 155/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.5865 - accuracy: 0.1923
# Epoch 156/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.5799 - accuracy: 0.2051
# Epoch 157/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.5732 - accuracy: 0.2051
# Epoch 158/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 2.5665 - accuracy: 0.2051
# Epoch 159/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.5597 - accuracy: 0.2051
# Epoch 160/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.5529 - accuracy: 0.2051
# Epoch 161/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.5460 - accuracy: 0.2051
# Epoch 162/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.5391 - accuracy: 0.2051
# Epoch 163/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.5322 - accuracy: 0.2051
# Epoch 164/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.5252 - accuracy: 0.2051
# Epoch 165/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 2.5181 - accuracy: 0.2051
# Epoch 166/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.5110 - accuracy: 0.2179
# Epoch 167/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.5038 - accuracy: 0.2179
# Epoch 168/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 2.4966 - accuracy: 0.2308
# Epoch 169/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 2.4895 - accuracy: 0.2308
# Epoch 170/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 2.4823 - accuracy: 0.2308
# Epoch 171/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.4751 - accuracy: 0.2308
# Epoch 172/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.4679 - accuracy: 0.2308
# Epoch 173/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.4606 - accuracy: 0.2308
# Epoch 174/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.4533 - accuracy: 0.2308
# Epoch 175/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.4460 - accuracy: 0.2308
# Epoch 176/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.4386 - accuracy: 0.2308
# Epoch 177/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.4311 - accuracy: 0.2308
# Epoch 178/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 2.4235 - accuracy: 0.2436
# Epoch 179/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 2.4159 - accuracy: 0.2436
# Epoch 180/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.4083 - accuracy: 0.2436
# Epoch 181/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.4006 - accuracy: 0.2564
# Epoch 182/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.3928 - accuracy: 0.2564
# Epoch 183/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 2.3850 - accuracy: 0.2692
# Epoch 184/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 2.3771 - accuracy: 0.2692
# Epoch 185/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.3693 - accuracy: 0.2692
# Epoch 186/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.3615 - accuracy: 0.2692
# Epoch 187/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 2.3535 - accuracy: 0.2692
# Epoch 188/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 2.3456 - accuracy: 0.2692
# Epoch 189/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.3374 - accuracy: 0.2692
# Epoch 190/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 2.3291 - accuracy: 0.2692
# Epoch 191/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.3207 - accuracy: 0.2692
# Epoch 192/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.3122 - accuracy: 0.2821
# Epoch 193/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.3037 - accuracy: 0.2821
# Epoch 194/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.2953 - accuracy: 0.2949
# Epoch 195/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 2.2868 - accuracy: 0.2949
# Epoch 196/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 2.2782 - accuracy: 0.2949
# Epoch 197/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.2696 - accuracy: 0.2949
# Epoch 198/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.2610 - accuracy: 0.2949
# Epoch 199/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.2523 - accuracy: 0.2949
# Epoch 200/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.2436 - accuracy: 0.2949
# Epoch 201/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.2348 - accuracy: 0.3077
# Epoch 202/1000
# 1/1 [==============================] - 0s 17ms/step - loss: 2.2261 - accuracy: 0.3077
# Epoch 203/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 2.2172 - accuracy: 0.3077
# Epoch 204/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.2084 - accuracy: 0.3077
# Epoch 205/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 2.1995 - accuracy: 0.3205
# Epoch 206/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 2.1907 - accuracy: 0.3333
# Epoch 207/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.1817 - accuracy: 0.3333
# Epoch 208/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.1727 - accuracy: 0.3333
# Epoch 209/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2.1637 - accuracy: 0.3333
# Epoch 210/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.1547 - accuracy: 0.3333
# Epoch 211/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.1457 - accuracy: 0.3462
# Epoch 212/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.1367 - accuracy: 0.3462
# Epoch 213/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 2.1276 - accuracy: 0.3462
# Epoch 214/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.1185 - accuracy: 0.3590
# Epoch 215/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.1093 - accuracy: 0.3590
# Epoch 216/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.1000 - accuracy: 0.3590
# Epoch 217/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 2.0908 - accuracy: 0.3590
# Epoch 218/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.0816 - accuracy: 0.3590
# Epoch 219/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.0724 - accuracy: 0.3590
# Epoch 220/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 2.0632 - accuracy: 0.3590
# Epoch 221/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.0540 - accuracy: 0.3590
# Epoch 222/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 2.0447 - accuracy: 0.3590
# Epoch 223/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.0355 - accuracy: 0.3590
# Epoch 224/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.0262 - accuracy: 0.3590
# Epoch 225/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.0169 - accuracy: 0.3590
# Epoch 226/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 2.0076 - accuracy: 0.3590
# Epoch 227/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.9984 - accuracy: 0.3590
# Epoch 228/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.9891 - accuracy: 0.3718
# Epoch 229/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.9799 - accuracy: 0.3718
# Epoch 230/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.9707 - accuracy: 0.3718
# Epoch 231/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.9614 - accuracy: 0.3718
# Epoch 232/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.9522 - accuracy: 0.3718
# Epoch 233/1000
# 1/1 [==============================] - 0s 17ms/step - loss: 1.9430 - accuracy: 0.3718
# Epoch 234/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 1.9337 - accuracy: 0.3718
# Epoch 235/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.9245 - accuracy: 0.3718
# Epoch 236/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.9153 - accuracy: 0.3718
# Epoch 237/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.9061 - accuracy: 0.3718
# Epoch 238/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.8969 - accuracy: 0.3718
# Epoch 239/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 1.8878 - accuracy: 0.3718
# Epoch 240/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.8785 - accuracy: 0.3718
# Epoch 241/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.8693 - accuracy: 0.3846
# Epoch 242/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.8601 - accuracy: 0.3846
# Epoch 243/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.8509 - accuracy: 0.3846
# Epoch 244/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.8417 - accuracy: 0.3974
# Epoch 245/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.8326 - accuracy: 0.4103
# Epoch 246/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.8235 - accuracy: 0.4103
# Epoch 247/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.8143 - accuracy: 0.4231
# Epoch 248/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.8052 - accuracy: 0.4359
# Epoch 249/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 1.7960 - accuracy: 0.4359
# Epoch 250/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.7869 - accuracy: 0.4359
# Epoch 251/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.7778 - accuracy: 0.4359
# Epoch 252/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 1.7687 - accuracy: 0.4359
# Epoch 253/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 1.7596 - accuracy: 0.4359
# Epoch 254/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.7505 - accuracy: 0.4487
# Epoch 255/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.7414 - accuracy: 0.4615
# Epoch 256/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7324 - accuracy: 0.4487
# Epoch 257/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.7233 - accuracy: 0.4615
# Epoch 258/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7143 - accuracy: 0.4872
# Epoch 259/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.7052 - accuracy: 0.4872
# Epoch 260/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.6961 - accuracy: 0.4872
# Epoch 261/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.6871 - accuracy: 0.4872
# Epoch 262/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6781 - accuracy: 0.4872
# Epoch 263/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.6690 - accuracy: 0.4872
# Epoch 264/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6600 - accuracy: 0.4872
# Epoch 265/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.6509 - accuracy: 0.5128
# Epoch 266/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.6419 - accuracy: 0.5128
# Epoch 267/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.6329 - accuracy: 0.5256
# Epoch 268/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.6239 - accuracy: 0.5513
# Epoch 269/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.6149 - accuracy: 0.5641
# Epoch 270/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 1.6059 - accuracy: 0.5641
# Epoch 271/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5970 - accuracy: 0.5641
# Epoch 272/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.5880 - accuracy: 0.5641
# Epoch 273/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.5791 - accuracy: 0.5897
# Epoch 274/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.5701 - accuracy: 0.5897
# Epoch 275/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.5612 - accuracy: 0.5897
# Epoch 276/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.5523 - accuracy: 0.5897
# Epoch 277/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.5434 - accuracy: 0.5897
# Epoch 278/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 1.5345 - accuracy: 0.6154
# Epoch 279/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.5257 - accuracy: 0.6154
# Epoch 280/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 1.5168 - accuracy: 0.6154
# Epoch 281/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.5080 - accuracy: 0.6154
# Epoch 282/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 1.4991 - accuracy: 0.6154
# Epoch 283/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.4903 - accuracy: 0.6154
# Epoch 284/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4815 - accuracy: 0.6282
# Epoch 285/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.4727 - accuracy: 0.6282
# Epoch 286/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.4640 - accuracy: 0.6282
# Epoch 287/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4553 - accuracy: 0.6282
# Epoch 288/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4465 - accuracy: 0.6282
# Epoch 289/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4378 - accuracy: 0.6282
# Epoch 290/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4292 - accuracy: 0.6538
# Epoch 291/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4205 - accuracy: 0.6538
# Epoch 292/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4119 - accuracy: 0.6538
# Epoch 293/1000
# 1/1 [==============================] - 0s 16ms/step - loss: 1.4032 - accuracy: 0.6538
# Epoch 294/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3946 - accuracy: 0.6795
# Epoch 295/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3860 - accuracy: 0.6795
# Epoch 296/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.3775 - accuracy: 0.6795
# Epoch 297/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 1.3689 - accuracy: 0.6795
# Epoch 298/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.3604 - accuracy: 0.6795
# Epoch 299/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 1.3519 - accuracy: 0.6795
# Epoch 300/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3434 - accuracy: 0.6795
# Epoch 301/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3350 - accuracy: 0.6795
# Epoch 302/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3265 - accuracy: 0.6795
# Epoch 303/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.3182 - accuracy: 0.6795
# Epoch 304/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 1.3098 - accuracy: 0.6795
# Epoch 305/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.3014 - accuracy: 0.6795
# Epoch 306/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2931 - accuracy: 0.6795
# Epoch 307/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2847 - accuracy: 0.6795
# Epoch 308/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2765 - accuracy: 0.6795
# Epoch 309/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2682 - accuracy: 0.6795
# Epoch 310/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 1.2600 - accuracy: 0.6795
# Epoch 311/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2518 - accuracy: 0.6795
# Epoch 312/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2436 - accuracy: 0.6795
# Epoch 313/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2355 - accuracy: 0.6795
# Epoch 314/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2274 - accuracy: 0.6795
# Epoch 315/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2193 - accuracy: 0.6795
# Epoch 316/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.2112 - accuracy: 0.6923
# Epoch 317/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2033 - accuracy: 0.6923
# Epoch 318/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1953 - accuracy: 0.6923
# Epoch 319/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1873 - accuracy: 0.6923
# Epoch 320/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1794 - accuracy: 0.7051
# Epoch 321/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1715 - accuracy: 0.7051
# Epoch 322/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1636 - accuracy: 0.7051
# Epoch 323/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1558 - accuracy: 0.7051
# Epoch 324/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1480 - accuracy: 0.7051
# Epoch 325/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1403 - accuracy: 0.7179
# Epoch 326/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1326 - accuracy: 0.7179
# Epoch 327/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1249 - accuracy: 0.7179
# Epoch 328/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1173 - accuracy: 0.7179
# Epoch 329/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1097 - accuracy: 0.7179
# Epoch 330/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1022 - accuracy: 0.7179
# Epoch 331/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 1.0946 - accuracy: 0.7179
# Epoch 332/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0872 - accuracy: 0.7179
# Epoch 333/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0797 - accuracy: 0.7179
# Epoch 334/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0723 - accuracy: 0.7179
# Epoch 335/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0649 - accuracy: 0.7179
# Epoch 336/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0576 - accuracy: 0.7308
# Epoch 337/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0503 - accuracy: 0.7436
# Epoch 338/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0431 - accuracy: 0.7564
# Epoch 339/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0359 - accuracy: 0.7564
# Epoch 340/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0287 - accuracy: 0.7692
# Epoch 341/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0216 - accuracy: 0.7692
# Epoch 342/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0144 - accuracy: 0.7949
# Epoch 343/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0074 - accuracy: 0.7821
# Epoch 344/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0003 - accuracy: 0.7692
# Epoch 345/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.9933 - accuracy: 0.8077
# Epoch 346/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.9864 - accuracy: 0.8077
# Epoch 347/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.9794 - accuracy: 0.8077
# Epoch 348/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9725 - accuracy: 0.7821
# Epoch 349/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.9656 - accuracy: 0.7821
# Epoch 350/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9587 - accuracy: 0.8077
# Epoch 351/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9518 - accuracy: 0.8077
# Epoch 352/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9450 - accuracy: 0.8077
# Epoch 353/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.9382 - accuracy: 0.8077
# Epoch 354/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.9313 - accuracy: 0.8077
# Epoch 355/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.9244 - accuracy: 0.8205
# Epoch 356/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9176 - accuracy: 0.8205
# Epoch 357/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.9108 - accuracy: 0.8205
# Epoch 358/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.9039 - accuracy: 0.8205
# Epoch 359/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.8969 - accuracy: 0.8205
# Epoch 360/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.8900 - accuracy: 0.8205
# Epoch 361/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.8830 - accuracy: 0.8333
# Epoch 362/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.8761 - accuracy: 0.8333
# Epoch 363/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8691 - accuracy: 0.8333
# Epoch 364/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.8622 - accuracy: 0.8333
# Epoch 365/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.8555 - accuracy: 0.8333
# Epoch 366/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.8492 - accuracy: 0.8333
# Epoch 367/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8428 - accuracy: 0.8333
# Epoch 368/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.8365 - accuracy: 0.8333
# Epoch 369/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.8301 - accuracy: 0.8333
# Epoch 370/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.8238 - accuracy: 0.8333
# Epoch 371/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.8175 - accuracy: 0.8333
# Epoch 372/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.8112 - accuracy: 0.8333
# Epoch 373/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.8050 - accuracy: 0.8333
# Epoch 374/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7990 - accuracy: 0.8333
# Epoch 375/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.7929 - accuracy: 0.8333
# Epoch 376/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7868 - accuracy: 0.8333
# Epoch 377/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7809 - accuracy: 0.8462
# Epoch 378/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7749 - accuracy: 0.8462
# Epoch 379/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7690 - accuracy: 0.8462
# Epoch 380/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7631 - accuracy: 0.8462
# Epoch 381/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7571 - accuracy: 0.8590
# Epoch 382/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7513 - accuracy: 0.8590
# Epoch 383/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7454 - accuracy: 0.8590
# Epoch 384/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7396 - accuracy: 0.8462
# Epoch 385/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7339 - accuracy: 0.8462
# Epoch 386/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7281 - accuracy: 0.8590
# Epoch 387/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7224 - accuracy: 0.8718
# Epoch 388/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7168 - accuracy: 0.8718
# Epoch 389/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7111 - accuracy: 0.8718
# Epoch 390/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7055 - accuracy: 0.8718
# Epoch 391/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6999 - accuracy: 0.8718
# Epoch 392/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6944 - accuracy: 0.8718
# Epoch 393/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6888 - accuracy: 0.8718
# Epoch 394/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6833 - accuracy: 0.8718
# Epoch 395/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6778 - accuracy: 0.8846
# Epoch 396/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6724 - accuracy: 0.8846
# Epoch 397/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6670 - accuracy: 0.8846
# Epoch 398/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6615 - accuracy: 0.8846
# Epoch 399/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6562 - accuracy: 0.8846
# Epoch 400/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6508 - accuracy: 0.8846
# Epoch 401/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6455 - accuracy: 0.8974
# Epoch 402/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6402 - accuracy: 0.8974
# Epoch 403/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6349 - accuracy: 0.8974
# Epoch 404/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6296 - accuracy: 0.8974
# Epoch 405/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6244 - accuracy: 0.8974
# Epoch 406/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6192 - accuracy: 0.9103
# Epoch 407/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6140 - accuracy: 0.9231
# Epoch 408/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6088 - accuracy: 0.9231
# Epoch 409/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6037 - accuracy: 0.9359
# Epoch 410/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5985 - accuracy: 0.9359
# Epoch 411/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5935 - accuracy: 0.9359
# Epoch 412/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5884 - accuracy: 0.9359
# Epoch 413/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5833 - accuracy: 0.9359
# Epoch 414/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5783 - accuracy: 0.9359
# Epoch 415/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5733 - accuracy: 0.9359
# Epoch 416/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5683 - accuracy: 0.9359
# Epoch 417/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5633 - accuracy: 0.9359
# Epoch 418/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5583 - accuracy: 0.9359
# Epoch 419/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5534 - accuracy: 0.9487
# Epoch 420/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5485 - accuracy: 0.9487
# Epoch 421/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5436 - accuracy: 0.9487
# Epoch 422/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.5388 - accuracy: 0.9487
# Epoch 423/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5339 - accuracy: 0.9487
# Epoch 424/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5291 - accuracy: 0.9487
# Epoch 425/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5243 - accuracy: 0.9487
# Epoch 426/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5196 - accuracy: 0.9487
# Epoch 427/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5148 - accuracy: 0.9487
# Epoch 428/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5101 - accuracy: 0.9487
# Epoch 429/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5055 - accuracy: 0.9487
# Epoch 430/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5008 - accuracy: 0.9487
# Epoch 431/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4962 - accuracy: 0.9487
# Epoch 432/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4916 - accuracy: 0.9487
# Epoch 433/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4870 - accuracy: 0.9487
# Epoch 434/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4825 - accuracy: 0.9487
# Epoch 435/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4779 - accuracy: 0.9615
# Epoch 436/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4735 - accuracy: 0.9744
# Epoch 437/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4690 - accuracy: 0.9744
# Epoch 438/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.4646 - accuracy: 0.9744
# Epoch 439/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4602 - accuracy: 0.9872
# Epoch 440/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4558 - accuracy: 0.9872
# Epoch 441/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4515 - accuracy: 0.9872
# Epoch 442/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4472 - accuracy: 0.9872
# Epoch 443/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4429 - accuracy: 0.9872
# Epoch 444/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4387 - accuracy: 0.9872
# Epoch 445/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4345 - accuracy: 0.9872
# Epoch 446/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.4303 - accuracy: 0.9872
# Epoch 447/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4261 - accuracy: 0.9872
# Epoch 448/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4221 - accuracy: 0.9872
# Epoch 449/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4180 - accuracy: 0.9872
# Epoch 450/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4139 - accuracy: 0.9872
# Epoch 451/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.4099 - accuracy: 0.9872
# Epoch 452/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4060 - accuracy: 0.9872
# Epoch 453/1000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.4020 - accuracy: 0.9872
# Epoch 454/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3981 - accuracy: 0.9872
# Epoch 455/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3942 - accuracy: 0.9872
# Epoch 456/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.3904 - accuracy: 1.0000
# Epoch 457/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3866 - accuracy: 1.0000
# Epoch 458/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.3828 - accuracy: 1.0000
# Epoch 459/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3791 - accuracy: 1.0000
# Epoch 460/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3753 - accuracy: 1.0000
# Epoch 461/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3717 - accuracy: 1.0000
# Epoch 462/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3680 - accuracy: 1.0000
# Epoch 463/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3645 - accuracy: 1.0000
# Epoch 464/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3609 - accuracy: 1.0000
# Epoch 465/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3573 - accuracy: 1.0000
# Epoch 466/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3538 - accuracy: 1.0000
# Epoch 467/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3504 - accuracy: 1.0000
# Epoch 468/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3469 - accuracy: 1.0000
# Epoch 469/1000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.3435 - accuracy: 1.0000
# Epoch 470/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3401 - accuracy: 1.0000
# Epoch 471/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.3368 - accuracy: 1.0000
# Epoch 472/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3335 - accuracy: 1.0000
# Epoch 473/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3302 - accuracy: 1.0000
# Epoch 474/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3270 - accuracy: 1.0000
# Epoch 475/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3237 - accuracy: 1.0000
# Epoch 476/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3205 - accuracy: 1.0000
# Epoch 477/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3174 - accuracy: 1.0000
# Epoch 478/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3143 - accuracy: 1.0000
# Epoch 479/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3112 - accuracy: 1.0000
# Epoch 480/1000
# ...
# Epoch 842/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 843/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 844/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 845/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 846/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 847/1000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 848/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 849/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 850/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 851/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 852/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 853/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 854/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 855/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 856/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 857/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 858/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 859/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 860/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 861/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 862/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 863/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 864/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 865/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 866/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 867/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 868/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 869/1000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 870/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 871/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 872/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 873/1000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 874/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 875/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 876/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 877/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 878/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 879/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 880/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 881/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 882/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 883/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 884/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 885/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 886/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 887/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 888/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 889/1000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 890/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 891/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 892/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 893/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 894/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 895/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 896/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 897/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 898/1000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 899/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 900/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 901/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 902/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 903/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 904/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 905/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 906/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 907/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 908/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 909/1000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 910/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 911/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 912/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 913/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 914/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 915/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 916/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 917/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 918/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 919/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 920/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 921/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 922/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 923/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 924/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 925/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 926/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 927/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 928/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 929/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 930/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 931/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 932/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 933/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 934/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 935/1000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 936/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 937/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 938/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 939/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 940/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 941/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 942/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 943/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 944/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 945/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 946/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 947/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 948/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 949/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 950/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 951/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 952/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 953/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 954/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 955/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 956/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 957/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 958/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 959/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 960/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 961/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 962/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 963/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 964/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 965/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 966/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 967/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 968/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 969/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 970/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 971/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 972/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 973/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 974/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 975/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 976/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 977/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 978/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 979/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 980/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 981/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 982/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 983/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 984/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 985/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 986/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 987/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 988/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 989/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 990/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 991/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 992/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 993/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 994/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 995/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 996/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 997/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 998/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 999/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 1000/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0090 - accuracy: 1.0000

# %%
plt.plot(history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

acc = np.mean(history.history['accuracy'])
print("%s: %.2f%%" % ('accuracy',(acc*100)))
# Out:
# accuracy: 74.90%

# %%
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

loss = np.mean(history.history['loss'])
print("%s: %.2f%%" % ('loss',(loss*100)))
# Out:
# loss: 89.81%

# %%
# to save the trained model
model.save("chat_model")

import pickle

# to save the fitted tokenizer
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
# to save the fitted label encoder
with open('label_encoder.pickle', 'wb') as ecn_file:
    pickle.dump(lbl_encoder, ecn_file, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# INFO:tensorflow:Assets written to: chat_model/assets

# %%
# !pip install colorama
# Out:
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Installing collected packages: colorama
# Successfully installed colorama-0.4.4

# %%
import json 
import numpy as np
from tensorflow import keras
from sklearn.preprocessing import LabelEncoder

import colorama 
colorama.init()
from colorama import Fore, Style, Back

import random
import pickle

with open("intents.json") as file:
    data = json.load(file)


def chat():
    # load trained model
    model = keras.models.load_model('chat_model')

    # load tokenizer object
    with open('tokenizer.pickle', 'rb') as handle:
        tokenizer = pickle.load(handle)

    # load label encoder object
    with open('label_encoder.pickle', 'rb') as enc:
        lbl_encoder = pickle.load(enc)

    # parameters
    max_len = 20
    
    while True:
        print(Fore.LIGHTBLUE_EX + "User: " + Style.RESET_ALL, end="")
        inp = input()
        if inp.lower() == "quit":
            break

        result = model.predict(keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([inp]),
                                             truncating='post', maxlen=max_len))
        results_index = np.argmax(result)
        tag = lbl_encoder.inverse_transform([np.argmax(result)])
        print("Confidence Score : ",result[0][results_index])
        if result[0][results_index]>0.7:

          for i in data['intents']:
              if i['tag'] == tag:
                  print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL , np.random.choice(i['responses']))
        else:
          print("Out of context. Ask again!!")          

        # print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL,random.choice(responses))

print(Fore.YELLOW + "Start messaging with the bot (type quit to stop)!" + Style.RESET_ALL)
chat()
# Out:
# Start messaging with the bot (type quit to stop)!
# User: hello
# Confidence Score :  0.9865421
# ChatBot: Hi there, how can I help?
# User: help
# Confidence Score :  0.98035985
# ChatBot: Tell me your problem to assist you
# User: who are you
# Confidence Score :  0.9894962
# ChatBot: My name is JARVIS and I am your virtual assistant
# User: location
# Confidence Score :  0.9846126
# ChatBot: Stark Restaurant Saket near max Hospital
# User: quit

# %%
chat()
# Out:
# User: hi
# ChatBot: Good to see you again
# User: hello
# ChatBot: Hello, thanks for visiting
# User: menu
# ChatBot: We have South Indian food, North Indian food, Chinese Food and Italian food
# User: south
# ChatBot: Pizza, Lasagna, Ravioli, Spaghetti, Fried Eggplant, Red Wine
# User: south indian
# ChatBot: Masala Dosa, Sambar, Upma, Dosa, Idli Sambar, Vada Sambar, Onion Rava Dosa, Uttapam
# User: north indian
# ChatBot: Butter Chicken, Palak Paneer, Rajma Rice, Chicken Briyani, Mutton Biryani, Makhni Dal, Jalebi, Gulab Jamun, Curd, Butter Naan, Chapatti, Chole Bhature, Dum Aloo, Chicken Tikka, Aloo paratha, Rabri, Lassi, Faluda
# User: chinese
# ChatBot: Momos, Chowmein, Chilli Chicken, Spring Rolls, Chilli Potato, Fried Rice
# User: coplaint
# ChatBot: Momos, Chowmein, Chilli Chicken, Spring Rolls, Chilli Potato, Fried Rice
# User: complaint
# ChatBot: Momos, Chowmein, Chilli Chicken, Spring Rolls, Chilli Potato, Fried Rice
# User: i have a complaint
# ChatBot: Please provide us your complaint in order to assist you
# User: help
# ChatBot: Jalebi, Gulab Jamun, Curd, Rabri, Lassi, Faluda
# User: please
# ChatBot: Hi there, how can I help?
# User: your location
# ChatBot: Good to see you again
# User: qwho are you
# ChatBot: I am JARVIS
# User: what are you
# ChatBot: My name is JARVIS and I am your virtual assistant
# User: exit
# ChatBot: Momos, Chowmein, Chilli Chicken, Spring Rolls, Chilli Potato, Fried Rice
# User:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     582         """
# --> 583         parts = [self.recv(flags, copy=copy, track=track)]
#     584         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-e57ee30c65ef> in <module>()
# ----> 1 chat()
#
# <ipython-input-18-c30a04c1c9c5> in chat()
#      32     while True:
#      33         print(Fore.LIGHTBLUE_EX + "User: " + Style.RESET_ALL, end="")
# ---> 34         inp = input()
#      35         if inp.lower() == "quit":
#      36             break
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:
